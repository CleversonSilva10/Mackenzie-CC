# %%
import pandas as pd

# %%
df = pd.read_csv("aula4_housingprices.csv")

# %%
df = df.rename(columns={
    "longitude": "longitude",
    "latitude": "latitude",
    "housing_median_age": "idade_mediana_das_casas",
    "total_rooms": "total_de_comodos",
    "total_bedrooms": "total_de_quartos",
    "population": "populacao",
    "households": "domicilios",
    "median_income": "renda_mediana",
    "median_house_value": "valor_mediano_das_casas",
    "ocean_proximity": "proximidade_do_oceano"
})

df
# Out:
#        longitude  latitude  idade_mediana_das_casas  total_de_comodos  \
# 0        -122.23     37.88                     41.0             880.0
# 1        -122.22     37.86                     21.0            7099.0
# 2        -122.24     37.85                     52.0            1467.0
# 3        -122.25     37.85                     52.0            1274.0
# 4        -122.25     37.85                     52.0            1627.0
# ...          ...       ...                      ...               ...
# 20635    -121.09     39.48                     25.0            1665.0
# 20636    -121.21     39.49                     18.0             697.0
# 20637    -121.22     39.43                     17.0            2254.0
# 20638    -121.32     39.43                     18.0            1860.0
# 20639    -121.24     39.37                     16.0            2785.0
#
#        total_de_quartos  populacao  domicilios  renda_mediana  \
# 0                 129.0      322.0       126.0         8.3252
# ...
